# %%
# !nvidia-smi
# Out:
# Sun Apr 18 10:23:56 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.67       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0    24W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Github Codes

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
from tqdm.auto import tqdm
import torchvision
import torchvision.transforms as transforms
import datetime
import os
from torch.utils.tensorboard import SummaryWriter
import shutil

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Data
print('==> Preparing data..')
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

trainset = torchvision.datasets.CIFAR10(
    root='/content/drive/MyDrive/CIFAR10', train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(
    trainset, batch_size=128, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(
    root='/content/drive/MyDrive/CIFAR10', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(
    testset, batch_size=100, shuffle=False, num_workers=2)

current_time = datetime.datetime.now() + datetime.timedelta(hours= 9)
current_time = current_time.strftime('%Y-%m-%d-%H:%M')

saved_loc = os.path.join('/content/drive/MyDrive/ResNet_Result', current_time)
if os.path.exists(saved_loc):
    shutil.rmtree(saved_loc)
os.mkdir(saved_loc)

print("결과 저장 위치: ", saved_loc)

writer = SummaryWriter(saved_loc)
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# 결과 저장 위치:  /content/drive/MyDrive/ResNet_Result/2021-04-18-19:26

# %%
# Model
print('==> Building model..')

class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(
            in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class Bottleneck(nn.Module):
    expansion = 4

    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(planes, self.expansion *
                               planes, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(self.expansion*planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512*block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

#net = ResNet(BasicBlock, [2, 2, 2, 2]) # ResNet18
net = ResNet(BasicBlock, [3, 4, 6, 3]) # ResNet34

net = net.to(device)
cudnn.benchmark = True

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.1,
                      momentum=0.9, weight_decay=5e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200)

best_acc = 0
# Out:
# ==> Building model..

# %%
# Training
def train(epoch):
    print('\nEpoch: %d' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    batch_count = 0
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
        batch_count += 1

    print("Train Loss : {:.3f} | Train Acc: {:.3f}".format(train_loss / batch_count, 100.*correct/total))
    final_loss = train_loss / batch_count
    final_acc = 100.*correct / total
    return final_loss, final_acc


def test(epoch):
    global best_acc
    net.eval()
    test_loss = 0
    correct = 0
    total = 0
    batch_count = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
            batch_count += 1


    print("Test Loss : {:.3f} | Test Acc: {:.3f}".format(test_loss / batch_count, 100.*correct/total))

    # Save checkpoint.
    acc = 100.*correct/total
    if acc > best_acc:
        print('Saving..')
        state = {
            'net': net.state_dict(),
            'acc': acc,
            'epoch': epoch,
        }
        if not os.path.isdir(os.path.join(saved_loc, 'checkpoint')):
            os.mkdir(os.path.join(saved_loc, 'checkpoint'))
        torch.save(state, os.path.join(saved_loc, 'checkpoint/ckpt.pth'))
        best_acc = acc
    
    final_loss = test_loss / batch_count
    return final_loss, acc

# %%
for epoch in tqdm(range(200)):
    train_loss, train_acc = train(epoch)
    test_loss, test_acc = test(epoch)

    writer.add_scalars('Loss', {"Train Loss" : train_loss, "Test Loss" : test_loss}, epoch)
    writer.add_scalars('Accuracy', {"Train acc" : train_acc, "test acc" : test_acc}, epoch)
    
    scheduler.step()

writer.close()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=200.0), HTML(value='')))
# Epoch: 0
# Train Loss : 2.105 | Train Acc: 23.934
# Test Loss : 1.733 | Test Acc: 33.500
# Saving..
#
# Epoch: 1
# Train Loss : 1.598 | Train Acc: 40.808
# Test Loss : 1.438 | Test Acc: 47.020
# Saving..
#
# Epoch: 2
# Train Loss : 1.312 | Train Acc: 52.524
# Test Loss : 1.227 | Test Acc: 57.550
# Saving..
#
# Epoch: 3
# Train Loss : 1.097 | Train Acc: 60.714
# Test Loss : 1.097 | Test Acc: 61.870
# Saving..
#
# Epoch: 4
# Train Loss : 0.932 | Train Acc: 67.012
# Test Loss : 0.914 | Test Acc: 68.520
# Saving..
#
# Epoch: 5
# Train Loss : 0.806 | Train Acc: 71.752
# Test Loss : 0.841 | Test Acc: 71.530
# Saving..
#
# Epoch: 6
# Train Loss : 0.688 | Train Acc: 76.226
# Test Loss : 0.746 | Test Acc: 74.960
# Saving..
#
# Epoch: 7
# Train Loss : 0.619 | Train Acc: 78.758
# Test Loss : 0.905 | Test Acc: 71.830
#
# Epoch: 8
# Train Loss : 0.566 | Train Acc: 80.600
# Test Loss : 0.652 | Test Acc: 78.150
# Saving..
#
# Epoch: 9
# Train Loss : 0.528 | Train Acc: 81.888
# Test Loss : 0.564 | Test Acc: 81.280
# Saving..
#
# Epoch: 10
# Train Loss : 0.510 | Train Acc: 82.534
# Test Loss : 0.662 | Test Acc: 77.930
#
# Epoch: 11
# Train Loss : 0.487 | Train Acc: 83.290
# Test Loss : 0.617 | Test Acc: 79.400
#
# Epoch: 12
# Train Loss : 0.464 | Train Acc: 84.226
# Test Loss : 0.701 | Test Acc: 76.410
#
# Epoch: 13
# Train Loss : 0.448 | Train Acc: 84.690
# Test Loss : 0.717 | Test Acc: 77.100
#
# Epoch: 14
# Train Loss : 0.433 | Train Acc: 85.246
# Test Loss : 0.570 | Test Acc: 81.120
#
# Epoch: 15
# Train Loss : 0.425 | Train Acc: 85.614
# Test Loss : 0.705 | Test Acc: 77.930
#
# Epoch: 16
# Train Loss : 0.417 | Train Acc: 85.810
# Test Loss : 0.517 | Test Acc: 82.720
# Saving..
#
# Epoch: 17
# Train Loss : 0.410 | Train Acc: 85.986
# Test Loss : 0.604 | Test Acc: 79.520
#
# Epoch: 18
# Train Loss : 0.401 | Train Acc: 86.244
# Test Loss : 0.847 | Test Acc: 73.980
#
# Epoch: 19
# Train Loss : 0.395 | Train Acc: 86.542
# Test Loss : 0.552 | Test Acc: 81.760
#
# Epoch: 20
# Train Loss : 0.385 | Train Acc: 86.910
# Test Loss : 0.591 | Test Acc: 80.690
#
# Epoch: 21
# Train Loss : 0.374 | Train Acc: 87.058
# Test Loss : 0.758 | Test Acc: 76.140
#
# Epoch: 22
# Train Loss : 0.378 | Train Acc: 87.028
# Test Loss : 0.635 | Test Acc: 79.480
#
# Epoch: 23
# Train Loss : 0.367 | Train Acc: 87.572
# Test Loss : 0.541 | Test Acc: 81.940
#
# Epoch: 24
# Train Loss : 0.355 | Train Acc: 87.964
# Test Loss : 0.768 | Test Acc: 76.820
#
# Epoch: 25
# Train Loss : 0.361 | Train Acc: 87.746
# Test Loss : 0.762 | Test Acc: 76.720
#
# Epoch: 26
# Train Loss : 0.348 | Train Acc: 88.236
# Test Loss : 0.539 | Test Acc: 82.850
# Saving..
#
# Epoch: 27
# Train Loss : 0.354 | Train Acc: 87.914
# Test Loss : 0.419 | Test Acc: 85.500
# Saving..
#
# Epoch: 28
# Train Loss : 0.346 | Train Acc: 88.094
# Test Loss : 0.638 | Test Acc: 80.640
#
# Epoch: 29
# Train Loss : 0.339 | Train Acc: 88.530
# Test Loss : 0.422 | Test Acc: 85.930
# Saving..
#
# Epoch: 30
# Train Loss : 0.339 | Train Acc: 88.372
# Test Loss : 0.525 | Test Acc: 82.540
#
# Epoch: 31
# Train Loss : 0.331 | Train Acc: 88.576
# Test Loss : 0.673 | Test Acc: 79.410
#
# Epoch: 32
# Train Loss : 0.334 | Train Acc: 88.540
# Test Loss : 0.468 | Test Acc: 84.470
#
# Epoch: 33
# Train Loss : 0.329 | Train Acc: 88.722
# Test Loss : 0.408 | Test Acc: 86.380
# Saving..
#
# Epoch: 34
# Train Loss : 0.327 | Train Acc: 88.832
# Test Loss : 0.724 | Test Acc: 77.560
#
# Epoch: 35
# Train Loss : 0.321 | Train Acc: 89.086
# Test Loss : 0.601 | Test Acc: 80.550
#
# Epoch: 36
# Train Loss : 0.318 | Train Acc: 89.330
# Test Loss : 0.443 | Test Acc: 84.730
#
# Epoch: 37
# Train Loss : 0.318 | Train Acc: 89.096
# Test Loss : 0.432 | Test Acc: 85.440
#
# Epoch: 38
# Train Loss : 0.315 | Train Acc: 89.164
# Test Loss : 0.568 | Test Acc: 81.890
#
# Epoch: 39
# Train Loss : 0.311 | Train Acc: 89.320
# Test Loss : 0.480 | Test Acc: 83.950
#
# Epoch: 40
# Train Loss : 0.311 | Train Acc: 89.378
# Test Loss : 0.439 | Test Acc: 85.140
#
# Epoch: 41
# Train Loss : 0.310 | Train Acc: 89.632
# Test Loss : 0.501 | Test Acc: 83.790
#
# Epoch: 42
# Train Loss : 0.303 | Train Acc: 89.724
# Test Loss : 0.448 | Test Acc: 85.330
#
# Epoch: 43
# Train Loss : 0.303 | Train Acc: 89.706
# Test Loss : 0.598 | Test Acc: 81.530
#
# Epoch: 44
# Train Loss : 0.303 | Train Acc: 89.810
# Test Loss : 0.437 | Test Acc: 85.890
#
# Epoch: 45
# Train Loss : 0.304 | Train Acc: 89.714
# Test Loss : 0.568 | Test Acc: 82.510
#
# Epoch: 46
# Train Loss : 0.296 | Train Acc: 89.850
# Test Loss : 0.548 | Test Acc: 82.530
#
# Epoch: 47
# Train Loss : 0.296 | Train Acc: 89.896
# Test Loss : 0.458 | Test Acc: 84.950
#
# Epoch: 48
# Train Loss : 0.288 | Train Acc: 90.228
# Test Loss : 0.497 | Test Acc: 84.680
#
# Epoch: 49
# Train Loss : 0.292 | Train Acc: 90.126
# Test Loss : 0.404 | Test Acc: 86.190
#
# Epoch: 50
# Train Loss : 0.286 | Train Acc: 90.234
# Test Loss : 0.470 | Test Acc: 85.220
#
# Epoch: 51
# Train Loss : 0.289 | Train Acc: 90.242
# Test Loss : 0.438 | Test Acc: 85.810
#
# Epoch: 52
# Train Loss : 0.285 | Train Acc: 90.288
# Test Loss : 0.445 | Test Acc: 85.480
#
# Epoch: 53
# Train Loss : 0.284 | Train Acc: 90.338
# Test Loss : 0.460 | Test Acc: 85.160
#
# Epoch: 54
# Train Loss : 0.283 | Train Acc: 90.306
# Test Loss : 0.481 | Test Acc: 84.440
#
# Epoch: 55
# Train Loss : 0.276 | Train Acc: 90.514
# Test Loss : 0.408 | Test Acc: 86.150
#
# Epoch: 56
# Train Loss : 0.280 | Train Acc: 90.410
# Test Loss : 0.528 | Test Acc: 84.170
#
# Epoch: 57
# Train Loss : 0.277 | Train Acc: 90.634
# Test Loss : 0.376 | Test Acc: 87.330
# Saving..
#
# Epoch: 58
# Train Loss : 0.269 | Train Acc: 90.848
# Test Loss : 0.423 | Test Acc: 86.220
#
# Epoch: 59
# Train Loss : 0.272 | Train Acc: 90.944
# Test Loss : 0.414 | Test Acc: 86.610
#
# Epoch: 60
# Train Loss : 0.271 | Train Acc: 90.732
# Test Loss : 0.398 | Test Acc: 86.980
#
# Epoch: 61
# Train Loss : 0.267 | Train Acc: 90.838
# Test Loss : 0.499 | Test Acc: 83.530
#
# Epoch: 62
# Train Loss : 0.266 | Train Acc: 90.972
# Test Loss : 0.372 | Test Acc: 87.370
# Saving..
#
# Epoch: 63
# Train Loss : 0.265 | Train Acc: 91.006
# Test Loss : 0.530 | Test Acc: 83.830
#
# Epoch: 64
# Train Loss : 0.257 | Train Acc: 91.286
# Test Loss : 0.390 | Test Acc: 87.250
#
# Epoch: 65
# Train Loss : 0.261 | Train Acc: 91.036
# Test Loss : 0.563 | Test Acc: 82.400
#
# Epoch: 66
# Train Loss : 0.259 | Train Acc: 91.196
# Test Loss : 0.515 | Test Acc: 84.450
#
# Epoch: 67
# Train Loss : 0.257 | Train Acc: 91.200
# Test Loss : 0.478 | Test Acc: 84.720
#
# Epoch: 68
# Train Loss : 0.255 | Train Acc: 91.384
# Test Loss : 0.364 | Test Acc: 87.940
# Saving..
#
# Epoch: 69
# Train Loss : 0.253 | Train Acc: 91.422
# Test Loss : 0.432 | Test Acc: 85.700
#
# Epoch: 70
# Train Loss : 0.250 | Train Acc: 91.506
# Test Loss : 0.529 | Test Acc: 83.830
#
# Epoch: 71
# Train Loss : 0.246 | Train Acc: 91.656
# Test Loss : 0.436 | Test Acc: 86.460
#
# Epoch: 72
# Train Loss : 0.242 | Train Acc: 91.750
# Test Loss : 0.360 | Test Acc: 87.730
#
# Epoch: 73
# Train Loss : 0.245 | Train Acc: 91.536
# Test Loss : 0.514 | Test Acc: 83.550
#
# Epoch: 74
# Train Loss : 0.240 | Train Acc: 91.880
# Test Loss : 0.425 | Test Acc: 87.000
#
# Epoch: 75
# Train Loss : 0.238 | Train Acc: 91.790
# Test Loss : 0.429 | Test Acc: 86.350
#
# Epoch: 76
# Train Loss : 0.236 | Train Acc: 92.026
# Test Loss : 0.434 | Test Acc: 86.320
#
# Epoch: 77
# Train Loss : 0.232 | Train Acc: 92.148
# Test Loss : 0.453 | Test Acc: 85.970
#
# Epoch: 78
# Train Loss : 0.233 | Train Acc: 92.116
# Test Loss : 0.417 | Test Acc: 86.230
#
# Epoch: 79
# Train Loss : 0.231 | Train Acc: 92.034
# Test Loss : 0.455 | Test Acc: 85.600
#
# Epoch: 80
# Train Loss : 0.228 | Train Acc: 92.222
# Test Loss : 0.422 | Test Acc: 86.490
#
# Epoch: 81
# Train Loss : 0.225 | Train Acc: 92.304
# Test Loss : 0.373 | Test Acc: 87.700
#
# Epoch: 82
# Train Loss : 0.221 | Train Acc: 92.524
# Test Loss : 0.329 | Test Acc: 89.170
# Saving..
#
# Epoch: 83
# Train Loss : 0.219 | Train Acc: 92.432
# Test Loss : 0.341 | Test Acc: 89.040
#
# Epoch: 84
# Train Loss : 0.217 | Train Acc: 92.590
# Test Loss : 0.379 | Test Acc: 87.530
#
# Epoch: 85
# Train Loss : 0.215 | Train Acc: 92.682
# Test Loss : 0.444 | Test Acc: 85.860
#
# Epoch: 86
# Train Loss : 0.217 | Train Acc: 92.646
# Test Loss : 0.371 | Test Acc: 87.760
#
# Epoch: 87
# Train Loss : 0.212 | Train Acc: 92.780
# Test Loss : 0.346 | Test Acc: 88.980
#
# Epoch: 88
# Train Loss : 0.205 | Train Acc: 92.938
# Test Loss : 0.350 | Test Acc: 88.360
#
# Epoch: 89
# Train Loss : 0.203 | Train Acc: 93.052
# Test Loss : 0.421 | Test Acc: 86.740
#
# Epoch: 90
# Train Loss : 0.200 | Train Acc: 93.260
# Test Loss : 0.294 | Test Acc: 90.340
# Saving..
#
# Epoch: 91
# Train Loss : 0.198 | Train Acc: 93.208
# Test Loss : 0.399 | Test Acc: 87.380
#
# Epoch: 92
# Train Loss : 0.197 | Train Acc: 93.342
# Test Loss : 0.327 | Test Acc: 89.290
#
# Epoch: 93
# Train Loss : 0.195 | Train Acc: 93.428
# Test Loss : 0.357 | Test Acc: 88.360
#
# Epoch: 94
# Train Loss : 0.193 | Train Acc: 93.402
# Test Loss : 0.403 | Test Acc: 87.180
#
# Epoch: 95
# Train Loss : 0.189 | Train Acc: 93.572
# Test Loss : 0.367 | Test Acc: 88.740
#
# Epoch: 96
# Train Loss : 0.193 | Train Acc: 93.260
# Test Loss : 0.439 | Test Acc: 85.640
#
# Epoch: 97
# Train Loss : 0.189 | Train Acc: 93.568
# Test Loss : 0.435 | Test Acc: 85.990
#
# Epoch: 98
# Train Loss : 0.183 | Train Acc: 93.796
# Test Loss : 0.338 | Test Acc: 89.290
#
# Epoch: 99
# Train Loss : 0.179 | Train Acc: 93.986
# Test Loss : 0.296 | Test Acc: 90.380
# Saving..
#
# Epoch: 100
# Train Loss : 0.181 | Train Acc: 93.930
# Test Loss : 0.325 | Test Acc: 89.460
#
# Epoch: 101
# Train Loss : 0.176 | Train Acc: 93.982
# Test Loss : 0.290 | Test Acc: 90.770
# Saving..
#
# Epoch: 102
# Train Loss : 0.170 | Train Acc: 94.178
# Test Loss : 0.333 | Test Acc: 89.020
#
# Epoch: 103
# Train Loss : 0.172 | Train Acc: 94.042
# Test Loss : 0.375 | Test Acc: 87.970
#
# Epoch: 104
# Train Loss : 0.166 | Train Acc: 94.410
# Test Loss : 0.375 | Test Acc: 88.220
#
# Epoch: 105
# Train Loss : 0.170 | Train Acc: 94.202
# Test Loss : 0.381 | Test Acc: 88.430
#
# Epoch: 106
# Train Loss : 0.165 | Train Acc: 94.388
# Test Loss : 0.351 | Test Acc: 88.890
#
# Epoch: 107
# Train Loss : 0.161 | Train Acc: 94.476
# Test Loss : 0.382 | Test Acc: 87.990
#
# Epoch: 108
# Train Loss : 0.155 | Train Acc: 94.760
# Test Loss : 0.320 | Test Acc: 89.920
#
# Epoch: 109
# Train Loss : 0.154 | Train Acc: 94.724
# Test Loss : 0.307 | Test Acc: 90.360
#
# Epoch: 110
# Train Loss : 0.155 | Train Acc: 94.728
# Test Loss : 0.303 | Test Acc: 90.340
#
# Epoch: 111
# Train Loss : 0.144 | Train Acc: 95.118
# Test Loss : 0.318 | Test Acc: 89.920
#
# Epoch: 112
# Train Loss : 0.143 | Train Acc: 95.152
# Test Loss : 0.281 | Test Acc: 91.100
# Saving..
#
# Epoch: 113
# Train Loss : 0.145 | Train Acc: 95.074
# Test Loss : 0.370 | Test Acc: 88.620
#
# Epoch: 114
# Train Loss : 0.142 | Train Acc: 95.158
# Test Loss : 0.327 | Test Acc: 89.460
#
# Epoch: 115
# Train Loss : 0.144 | Train Acc: 95.064
# Test Loss : 0.331 | Test Acc: 89.740
#
# Epoch: 116
# Train Loss : 0.133 | Train Acc: 95.582
# Test Loss : 0.311 | Test Acc: 90.270
#
# Epoch: 117
# Train Loss : 0.132 | Train Acc: 95.570
# Test Loss : 0.280 | Test Acc: 91.120
# Saving..
#
# Epoch: 118
# Train Loss : 0.130 | Train Acc: 95.582
# Test Loss : 0.304 | Test Acc: 90.440
#
# Epoch: 119
# Train Loss : 0.127 | Train Acc: 95.668
# Test Loss : 0.322 | Test Acc: 90.060
#
# Epoch: 120
# Train Loss : 0.125 | Train Acc: 95.752
# Test Loss : 0.321 | Test Acc: 90.140
#
# Epoch: 121
# Train Loss : 0.120 | Train Acc: 95.914
# Test Loss : 0.370 | Test Acc: 88.360
#
# Epoch: 122
# Train Loss : 0.119 | Train Acc: 95.972
# Test Loss : 0.266 | Test Acc: 91.860
# Saving..
#
# Epoch: 123
# Train Loss : 0.118 | Train Acc: 96.088
# Test Loss : 0.306 | Test Acc: 90.790
#
# Epoch: 124
# Train Loss : 0.115 | Train Acc: 96.116
# Test Loss : 0.322 | Test Acc: 89.830
#
# Epoch: 125
# Train Loss : 0.114 | Train Acc: 96.100
# Test Loss : 0.272 | Test Acc: 91.110
#
# Epoch: 126
# Train Loss : 0.106 | Train Acc: 96.394
# Test Loss : 0.283 | Test Acc: 91.600
#
# Epoch: 127
# Train Loss : 0.102 | Train Acc: 96.564
# Test Loss : 0.268 | Test Acc: 91.440
#
# Epoch: 128
# Train Loss : 0.103 | Train Acc: 96.606
# Test Loss : 0.243 | Test Acc: 92.240
# Saving..
#
# Epoch: 129
# Train Loss : 0.100 | Train Acc: 96.716
# Test Loss : 0.285 | Test Acc: 91.550
#
# Epoch: 130
# Train Loss : 0.095 | Train Acc: 96.820
# Test Loss : 0.270 | Test Acc: 91.910
#
# Epoch: 131
# Train Loss : 0.093 | Train Acc: 96.902
# Test Loss : 0.313 | Test Acc: 90.630
#
# Epoch: 132
# Train Loss : 0.092 | Train Acc: 96.904
# Test Loss : 0.297 | Test Acc: 91.310
#
# Epoch: 133
# Train Loss : 0.087 | Train Acc: 97.082
# Test Loss : 0.276 | Test Acc: 91.910
#
# Epoch: 134
# Train Loss : 0.089 | Train Acc: 97.072
# Test Loss : 0.305 | Test Acc: 91.070
#
# Epoch: 135
# Train Loss : 0.081 | Train Acc: 97.202
# Test Loss : 0.257 | Test Acc: 92.570
# Saving..
#
# Epoch: 136
# Train Loss : 0.081 | Train Acc: 97.420
# Test Loss : 0.288 | Test Acc: 91.430
#
# Epoch: 137
# Train Loss : 0.076 | Train Acc: 97.482
# Test Loss : 0.322 | Test Acc: 90.460
#
# Epoch: 138
# Train Loss : 0.075 | Train Acc: 97.498
# Test Loss : 0.278 | Test Acc: 91.660
#
# Epoch: 139
# Train Loss : 0.070 | Train Acc: 97.652
# Test Loss : 0.302 | Test Acc: 91.610
#
# Epoch: 140
# Train Loss : 0.073 | Train Acc: 97.528
# Test Loss : 0.316 | Test Acc: 91.280
#
# Epoch: 141
# Train Loss : 0.071 | Train Acc: 97.624
# Test Loss : 0.258 | Test Acc: 92.080
#
# Epoch: 142
# Train Loss : 0.057 | Train Acc: 98.194
# Test Loss : 0.305 | Test Acc: 91.800
#
# Epoch: 143
# Train Loss : 0.061 | Train Acc: 97.996
# Test Loss : 0.301 | Test Acc: 91.480
#
# Epoch: 144
# Train Loss : 0.060 | Train Acc: 98.030
# Test Loss : 0.252 | Test Acc: 92.750
# Saving..
#
# Epoch: 145
# Train Loss : 0.057 | Train Acc: 98.130
# Test Loss : 0.263 | Test Acc: 92.660
#
# Epoch: 146
# Train Loss : 0.053 | Train Acc: 98.284
# Test Loss : 0.282 | Test Acc: 92.280
#
# Epoch: 147
# Train Loss : 0.050 | Train Acc: 98.334
# Test Loss : 0.274 | Test Acc: 92.360
#
# Epoch: 148
# Train Loss : 0.047 | Train Acc: 98.426
# Test Loss : 0.269 | Test Acc: 92.670
#
# Epoch: 149
# Train Loss : 0.047 | Train Acc: 98.492
# Test Loss : 0.253 | Test Acc: 92.760
# Saving..
#
# Epoch: 150
# Train Loss : 0.045 | Train Acc: 98.526
# Test Loss : 0.246 | Test Acc: 93.430
# Saving..
#
# Epoch: 151
# Train Loss : 0.042 | Train Acc: 98.610
# Test Loss : 0.286 | Test Acc: 92.250
#
# Epoch: 152
# Train Loss : 0.036 | Train Acc: 98.830
# Test Loss : 0.247 | Test Acc: 93.370
#
# Epoch: 153
# Train Loss : 0.038 | Train Acc: 98.726
# Test Loss : 0.251 | Test Acc: 93.200
#
# Epoch: 154
# Train Loss : 0.032 | Train Acc: 98.982
# Test Loss : 0.268 | Test Acc: 92.890
#
# Epoch: 155
# Train Loss : 0.030 | Train Acc: 99.046
# Test Loss : 0.231 | Test Acc: 93.990
# Saving..
#
# Epoch: 156
# Train Loss : 0.025 | Train Acc: 99.206
# Test Loss : 0.258 | Test Acc: 92.970
#
# Epoch: 157
# Train Loss : 0.031 | Train Acc: 98.980
# Test Loss : 0.246 | Test Acc: 93.390
#
# Epoch: 158
# Train Loss : 0.025 | Train Acc: 99.212
# Test Loss : 0.236 | Test Acc: 93.700
#
# Epoch: 159
# Train Loss : 0.023 | Train Acc: 99.302
# Test Loss : 0.229 | Test Acc: 94.010
# Saving..
#
# Epoch: 160
# Train Loss : 0.019 | Train Acc: 99.398
# Test Loss : 0.222 | Test Acc: 94.080
# Saving..
#
# Epoch: 161
# Train Loss : 0.021 | Train Acc: 99.350
# Test Loss : 0.220 | Test Acc: 94.350
# Saving..
#
# Epoch: 162
# Train Loss : 0.015 | Train Acc: 99.596
# Test Loss : 0.213 | Test Acc: 94.440
# Saving..
#
# Epoch: 163
# Train Loss : 0.013 | Train Acc: 99.590
# Test Loss : 0.222 | Test Acc: 94.410
#
# Epoch: 164
# Train Loss : 0.014 | Train Acc: 99.608
# Test Loss : 0.232 | Test Acc: 94.360
#
# Epoch: 165
# Train Loss : 0.013 | Train Acc: 99.612
# Test Loss : 0.223 | Test Acc: 94.510
# Saving..
#
# Epoch: 166
# Train Loss : 0.010 | Train Acc: 99.708
# Test Loss : 0.217 | Test Acc: 94.370
#
# Epoch: 167
# Train Loss : 0.010 | Train Acc: 99.696
# Test Loss : 0.203 | Test Acc: 94.800
# Saving..
#
# Epoch: 168
# Train Loss : 0.007 | Train Acc: 99.824
# Test Loss : 0.200 | Test Acc: 95.250
# Saving..
#
# Epoch: 169
# Train Loss : 0.006 | Train Acc: 99.868
# Test Loss : 0.198 | Test Acc: 95.210
#
# Epoch: 170
# Train Loss : 0.006 | Train Acc: 99.842
# Test Loss : 0.204 | Test Acc: 94.940
#
# Epoch: 171
# Train Loss : 0.005 | Train Acc: 99.890
# Test Loss : 0.194 | Test Acc: 95.300
# Saving..
#
# Epoch: 172
# Train Loss : 0.005 | Train Acc: 99.910
# Test Loss : 0.189 | Test Acc: 95.460
# Saving..
#
# Epoch: 173
# Train Loss : 0.003 | Train Acc: 99.942
# Test Loss : 0.192 | Test Acc: 95.430
#
# Epoch: 174
# Train Loss : 0.003 | Train Acc: 99.950
# Test Loss : 0.194 | Test Acc: 95.590
# Saving..
#
# Epoch: 175
# Train Loss : 0.003 | Train Acc: 99.966
# Test Loss : 0.196 | Test Acc: 95.510
#
# Epoch: 176
# Train Loss : 0.002 | Train Acc: 99.984
# Test Loss : 0.183 | Test Acc: 95.710
# Saving..
#
# Epoch: 177
# Train Loss : 0.002 | Train Acc: 99.986
# Test Loss : 0.183 | Test Acc: 95.670
#
# Epoch: 178
# Train Loss : 0.002 | Train Acc: 99.972
# Test Loss : 0.185 | Test Acc: 95.700
#
# Epoch: 179
# Train Loss : 0.002 | Train Acc: 99.988
# Test Loss : 0.182 | Test Acc: 95.740
# Saving..
#
# Epoch: 180
# Train Loss : 0.002 | Train Acc: 99.988
# Test Loss : 0.179 | Test Acc: 95.670
#
# Epoch: 181
# Train Loss : 0.002 | Train Acc: 99.990
# Test Loss : 0.183 | Test Acc: 95.700
#
# Epoch: 182
# Train Loss : 0.001 | Train Acc: 99.996
# Test Loss : 0.180 | Test Acc: 95.840
# Saving..
#
# Epoch: 183
# Train Loss : 0.001 | Train Acc: 99.986
# Test Loss : 0.182 | Test Acc: 95.770
#
# Epoch: 184
# Train Loss : 0.002 | Train Acc: 99.992
# Test Loss : 0.180 | Test Acc: 95.900
# Saving..
#
# Epoch: 185
# Train Loss : 0.002 | Train Acc: 99.988
# Test Loss : 0.178 | Test Acc: 95.770
#
# Epoch: 186
# Train Loss : 0.001 | Train Acc: 99.988
# Test Loss : 0.177 | Test Acc: 95.890
#
# Epoch: 187
# Train Loss : 0.001 | Train Acc: 99.994
# Test Loss : 0.177 | Test Acc: 95.820
#
# Epoch: 188
# Train Loss : 0.001 | Train Acc: 99.998
# Test Loss : 0.177 | Test Acc: 95.860
#
# Epoch: 189
# Train Loss : 0.001 | Train Acc: 99.998
# Test Loss : 0.176 | Test Acc: 95.810
#
# Epoch: 190
# Train Loss : 0.002 | Train Acc: 99.988
# Test Loss : 0.176 | Test Acc: 95.930
# Saving..
#
# Epoch: 191
# Train Loss : 0.001 | Train Acc: 99.996
# Test Loss : 0.175 | Test Acc: 96.040
# Saving..
#
# Epoch: 192
# Train Loss : 0.001 | Train Acc: 99.990
# Test Loss : 0.176 | Test Acc: 95.910
#
# Epoch: 193
# Train Loss : 0.001 | Train Acc: 99.996
# Test Loss : 0.174 | Test Acc: 95.910
#
# Epoch: 194
# Train Loss : 0.001 | Train Acc: 99.998
# Test Loss : 0.176 | Test Acc: 95.940
#
# Epoch: 195
# Train Loss : 0.001 | Train Acc: 99.992
# Test Loss : 0.175 | Test Acc: 95.880
#
# Epoch: 196
# Train Loss : 0.001 | Train Acc: 99.996
# Test Loss : 0.175 | Test Acc: 95.880
#
# Epoch: 197
# Train Loss : 0.001 | Train Acc: 100.000
# Test Loss : 0.175 | Test Acc: 95.900
#
# Epoch: 198
# Train Loss : 0.001 | Train Acc: 100.000
# Test Loss : 0.176 | Test Acc: 95.950
#
# Epoch: 199
# Train Loss : 0.001 | Train Acc: 99.998
# Test Loss : 0.175 | Test Acc: 95.850

# %%
ckpt = torch.load('/content/drive/MyDrive/ResNet_Result/2021-04-18-19:26/checkpoint/ckpt.pth')

print(ckpt['acc'])
print(ckpt['epoch'])
# Out:
# 96.04
# 191

# %%
# %load_ext tensorboard
# %tensorboard --logdir='/content/drive/MyDrive/ResNet_Result/2021-04-18-19:26'
